# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv("./data/train/01.csv").head()
data = data.drop(['ID'],axis=1)
data
# Out:
#          種類  地域  市区町村コード 都道府県名   市区町村名    地区名  最寄駅：名称 最寄駅：距離（分）      間取り  \
# 0  中古マンション等 NaN     1101   北海道  札幌市中央区   北１条西   西１８丁目         5  オープンフロア
# 1  中古マンション等 NaN     1206   北海道     釧路市    浪花町      釧路        10     ３ＬＤＫ
# 2  中古マンション等 NaN     1103   北海道   札幌市東区  北４４条東  栄町(札幌)         5     ３ＬＤＫ
# 3  中古マンション等 NaN     1105   北海道  札幌市豊平区  月寒中央通      福住         4     ３ＬＤＫ
# 4  中古マンション等 NaN     1204   北海道     旭川市    宮下通      旭川         3       １Ｋ
#
#    面積（㎡）  ...  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）     都市計画 建ぺい率（％） 容積率（％）  \
# 0     85  ...      NaN      NaN         NaN     商業地域    80.0  400.0
# 1     70  ...      NaN      NaN         NaN  第１種住居地域    60.0  200.0
# 2     70  ...      NaN      NaN         NaN  第１種住居地域    60.0  200.0
# 3     85  ...      NaN      NaN         NaN    準工業地域    60.0  300.0
# 4     20  ...      NaN      NaN         NaN     商業地域    80.0  600.0
#
#          取引時点   改装  取引の事情等  取引価格（総額）_log
# 0  2019年第3四半期  改装済     NaN      6.963788
# ...

# %%
data.head()
# Out:
#         ID        種類  地域  市区町村コード 都道府県名   市区町村名    地区名  最寄駅：名称 最寄駅：距離（分）  \
# 0  1000809  中古マンション等 NaN     1101   北海道  札幌市中央区   北１条西   西１８丁目         5
# 1  1108719  中古マンション等 NaN     1206   北海道     釧路市    浪花町      釧路        10
# 2  1028203  中古マンション等 NaN     1103   北海道   札幌市東区  北４４条東  栄町(札幌)         5
# 3  1040438  中古マンション等 NaN     1105   北海道  札幌市豊平区  月寒中央通      福住         4
# 4  1100395  中古マンション等 NaN     1204   北海道     旭川市    宮下通      旭川         3
#
#        間取り  ...  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）     都市計画 建ぺい率（％） 容積率（％）  \
# 0  オープンフロア  ...      NaN      NaN         NaN     商業地域    80.0  400.0
# 1     ３ＬＤＫ  ...      NaN      NaN         NaN  第１種住居地域    60.0  200.0
# 2     ３ＬＤＫ  ...      NaN      NaN         NaN  第１種住居地域    60.0  200.0
# 3     ３ＬＤＫ  ...      NaN      NaN         NaN    準工業地域    60.0  300.0
# 4       １Ｋ  ...      NaN      NaN         NaN     商業地域    80.0  600.0
#
#          取引時点   改装  取引の事情等  取引価格（総額）_log
# 0  2019年第3四半期  改装済     NaN      6.963788
# ...
